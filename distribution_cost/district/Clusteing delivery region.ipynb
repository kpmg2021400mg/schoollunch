# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from shapely.geometry import Point
from shapely.geometry.polygon import LinearRing, Polygon
import folium
from shapely.geometry import Point, Polygon, LineString

# %%
elementary = "C:/Users/HyeJee Yang/Desktop/district/elementary/(B100)국토통계_인구정보-초등학생 인구 수(전체)-기초구역_서울특별시_202010/nlsp_017001016.shp"
middle = "C:/Users/HyeJee Yang/Desktop/district/middle/(B100)국토통계_인구정보-중학생 인구 수(전체)-기초구역_서울특별시_202010/nlsp_017001019.shp"
high = "C:/Users/HyeJee Yang/Desktop/district/high/(B100)국토통계_인구정보-고등학생 인구 수(전체)-기초구역_서울특별시_202010/nlsp_017001022.shp"

# %%
#우리에게 필요한 데이터를 생성하자
elestudent = gpd.read_file(elementary)
midstudent = gpd.read_file(middle)
histudent = gpd.read_file(high)

join1 = elestudent.merge(midstudent, on='gid')
join2 = join1.merge(histudent, on = 'gid')
select = ['gid', 'val_x', 'val_y', 'val','geometry']
join2 = join2[select]
join2['totval'] = join2['val_x'] + join2['val_y'] + join2['val']
select2 = ['gid','totval','geometry']
geodf = join2[select2]

# %%
geodf.head()
# Out:
#      gid  totval                                           geometry
# 0  01000    10.0  POLYGON ((956316.790 1965175.345, 956401.551 1...
# 1  01001    63.0  POLYGON ((957180.199 1962635.873, 957181.270 1...
# 2  01002   189.0  POLYGON ((956066.092 1963000.968, 956302.295 1...
# 3  01003   155.0  POLYGON ((956930.514 1962482.129, 956932.367 1...
# 4  01004    77.0  POLYGON ((956979.435 1962532.433, 956980.045 1...

# %%
geodf.dtypes
# Out:
# gid           object
# totval       float64
# geometry    geometry
# dtype: object

# %%
gdf = gpd.GeoDataFrame(geodf, geometry = 'geometry')

# %%
midaddress = pd.read_csv('C:/Users/HyeJee Yang/Desktop/school/gangnam.csv')
schools = pd.read_csv('C:/Users/HyeJee Yang/Desktop/school/schooldatabase.csv')

# %%
midaddress['gid'] = midaddress['gid'].astype(str)
schools['gid'] = schools['gid'].astype(str)

# %%
midaddress['zero'] = 0
midaddress['zero'] = midaddress['zero'].astype(str)
midaddress['prep'] = midaddress[['zero', 'gid']].apply(''.join, axis=1)
midaddress['gid'] = midaddress['prep']
del(midaddress['zero'])
del(midaddress['prep'])

# %%
schools['zero'] = 0
schools['zero'] = schools['zero'].astype(str)
schools['prep'] = schools[['zero', 'gid']].apply(''.join, axis=1)
schools['gid'] = schools['prep']
del(schools['zero'])
del(schools['prep'])

# %%
schools.head()
# Out:
#       code    gid
# 0  7091420  06328
# 1  7010058  06324
# 2  7091421  06321
# 3  7010059  06086
# 4  7010060  06324

# %%
midaddress
# Out:
#         gid            X            Y
# 0     06219  959880.7151  1944196.670
# 1     06219  959864.1654  1944233.109
# 2     06219  959854.5300  1944267.466
# 3     06216  959830.4520  1944346.196
# 4     06214  959698.5040  1944676.717
# ...     ...          ...          ...
# 2464  06292  960458.8517  1943333.303
# 2465  06294  960627.5574  1943394.472
# 2466  06293  960651.0780  1943439.097
# 2467  06270  959274.8432  1943126.208
# 2468  06272  959575.8802  1943767.828
#
# [2469 rows x 3 columns]

# %%
schoolmid = schools.merge(midaddress, on = 'gid')

# %%
schoolmid
# Out:
#         code    gid            X            Y
# 0    7010059  06086  960633.7705  1946168.325
# 1    7010059  06086  960554.2800  1946185.038
# 2    7010059  06086  960517.6699  1946222.438
# 3    7010520  06086  960633.7705  1946168.325
# 4    7010520  06086  960554.2800  1946185.038
# ..       ...    ...          ...          ...
# 336  7091455  06344  962879.0875  1943576.729
# 337  7010112  06009  959484.6022  1947887.057
# 338  7010112  06009  959514.9226  1947981.893
# 339  7010112  06009  959668.8628  1947649.881
# 340  7010112  06009  959740.8095  1947906.712
#
# [341 rows x 4 columns]

# %%
school_mid = gpd.GeoDataFrame(
    schoolmid, geometry=gpd.points_from_xy(schoolmid.X, schoolmid.Y))
school_point = school_mid.drop(['X', 'Y'], axis = 1)

# %%
school_points = gpd.GeoDataFrame(school_point, geometry = 'geometry')
school_points
# Out:
#         code    gid                        geometry
# 0    7010059  06086  POINT (960633.770 1946168.325)
# 1    7010059  06086  POINT (960554.280 1946185.038)
# 2    7010059  06086  POINT (960517.670 1946222.438)
# 3    7010520  06086  POINT (960633.770 1946168.325)
# 4    7010520  06086  POINT (960554.280 1946185.038)
# ..       ...    ...                             ...
# 336  7091455  06344  POINT (962879.088 1943576.729)
# 337  7010112  06009  POINT (959484.602 1947887.057)
# 338  7010112  06009  POINT (959514.923 1947981.893)
# 339  7010112  06009  POINT (959668.863 1947649.881)
# 340  7010112  06009  POINT (959740.809 1947906.712)
#
# [341 rows x 3 columns]

# %%
school_point = school_points.drop_duplicates("code", keep="first")

# %%
school_point.dtypes
# Out:
# code           int64
# gid           object
# geometry    geometry
# dtype: object

# %%
geopoint = geodf.merge(midaddress, on = 'gid')
geopoint = geopoint.drop(['geometry'], axis = 1)
geopoint
# Out:
#         gid  totval            X            Y
# 0     06000   595.0  957563.5597  1947369.052
# 1     06000   595.0  957679.7270  1947433.607
# 2     06001   692.0  958134.1111  1947548.280
# 3     06002   477.0  958211.0746  1948211.264
# 4     06003   168.0  958718.2728  1948250.341
# ...     ...     ...          ...          ...
# 2464  06377   214.0  965200.1404  1941340.941
# 2465  06377   214.0  965041.5339  1941047.303
# 2466  06378   203.0  965499.7272  1940898.889
# 2467  06378   203.0  965315.8412  1941531.776
# 2468  06378   203.0  965492.7855  1941337.536
#
# [2469 rows x 4 columns]

# %%
geopoint = geopoint.fillna(0)

# %%
wcss = []
for i in range(1, 62):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(geopoint)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 62), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 10, init = 'k-means++', random_state = 5,  max_iter=400)
y_kmeans = kmeans.fit_predict(geopoint)
k=pd.DataFrame(y_kmeans, columns=['cluster'])
geopoint_cluster=geopoint.join(k)

# %%
from geopandas import GeoDataFrame
geopoint_cluster = GeoDataFrame(geopoint_cluster)

# %%
geopoint_cluster.dtypes
# Out:
# gid         object
# totval     float64
# X          float64
# Y          float64
# cluster      int32
# dtype: object

# %%
clustered = gpd.GeoDataFrame(
    geopoint_cluster, geometry=gpd.points_from_xy(geopoint_cluster.X, geopoint_cluster.Y))
clustered = clustered.drop(['X', 'Y'], axis = 1)

# %%
f, ax = plt.subplots(1, figsize=(20, 15))
ax.set_title("Division", fontsize=40)
ax.set_axis_off()
geopoint_cluster.plot(column='cluster',cmap='Set2', ax=ax, markersize=80)
plt.show()

# %%
#그러나 모든 point들이 같은 인구값을 갖는 것은 아니다. 따라서 weight를 추가하여 다시 knn을 시도한다.
#강남구 소재의 초중고 학교 수는 78개이다.
#
weight = geopoint['totval']
wkmeans = KMeans(n_clusters = 40, init = 'k-means++', random_state = 5,  max_iter=400)
y_wkmeans = wkmeans.fit_predict(geopoint, sample_weight = weight)
wk=pd.DataFrame(y_wkmeans, columns=['cluster'])
geopoint_weighted=geopoint.join(wk)

# %%
weighted = gpd.GeoDataFrame(
    geopoint_weighted, geometry=gpd.points_from_xy(geopoint_cluster.X, geopoint_cluster.Y))
weighted = weighted.drop(['X', 'Y'], axis = 1)

# %%
f, ax = plt.subplots(1, figsize=(20, 15))
ax.set_title("Division", fontsize= 40)
ax.set_axis_off()
weighted.plot(column='cluster',cmap='Set2', ax=ax, markersize=50)
plt.show()

# %%
fin = weighted.merge(midaddress, on = 'gid')
fin = fin.drop(['X','Y'], axis = 1)
fin
# Out:
#          gid  totval  cluster                        geometry
# 0      06000   595.0       31  POINT (957563.560 1947369.052)
# 1      06000   595.0       31  POINT (957563.560 1947369.052)
# 2      06000   595.0       31  POINT (957679.727 1947433.607)
# 3      06000   595.0       31  POINT (957679.727 1947433.607)
# 4      06001   692.0        9  POINT (958134.111 1947548.280)
# ...      ...     ...      ...                             ...
# 41962  06378   203.0       33  POINT (965315.841 1941531.776)
# 41963  06378   203.0       33  POINT (965315.841 1941531.776)
# 41964  06378   203.0       17  POINT (965492.785 1941337.536)
# 41965  06378   203.0       17  POINT (965492.785 1941337.536)
# 41966  06378   203.0       17  POINT (965492.785 1941337.536)
#
# [41967 rows x 4 columns]

# %%
last = fin.merge(geodf, on = 'gid')
last = last.drop(['totval_x', 'geometry_x'], axis = 1)
last['geometry'] = last['geometry_y']
last['totval'] = last['totval_y']
last = last.drop(['totval_y', 'geometry_y'], axis = 1)
last
# Out:
#          gid  cluster                                           geometry  \
# 0      06000       31  POLYGON ((957747.959 1947667.995, 957788.776 1...
# 1      06000       31  POLYGON ((957747.959 1947667.995, 957788.776 1...
# 2      06000       31  POLYGON ((957747.959 1947667.995, 957788.776 1...
# 3      06000       31  POLYGON ((957747.959 1947667.995, 957788.776 1...
# 4      06001        9  POLYGON ((957704.604 1948608.078, 957913.592 1...
# ...      ...      ...                                                ...
# 41962  06378       33  POLYGON ((965235.276 1941639.659, 965237.968 1...
# 41963  06378       33  POLYGON ((965235.276 1941639.659, 965237.968 1...
# 41964  06378       17  POLYGON ((965235.276 1941639.659, 965237.968 1...
# 41965  06378       17  POLYGON ((965235.276 1941639.659, 965237.968 1...
# 41966  06378       17  POLYGON ((965235.276 1941639.659, 965237.968 1...
#
#        totval
# 0       595.0
# 1       595.0
# 2       595.0
# 3       595.0
# ...

# %%
first = last['cluster'] == 1
clustering1 = last[first]

second = last['cluster'] == 2
clustering2 = last[second]

third = last['cluster'] == 3
clustering3 = last[third]

fourth = last['cluster'] == 4
clustering4 = last[fourth]

fifth = last['cluster'] == 5
clustering5 = last[fifth]

sixth = last['cluster'] == 6
clustering6 = last[sixth]

seventh = last['cluster'] == 7
clustering7 = last[seventh]

eighth = last['cluster'] == 8
clustering8 = last[eighth]

ninth = last['cluster'] == 9
clustering9 = last[ninth]

tenth = last['cluster'] == 10
clustering10 = last[tenth]

oneone = last['cluster'] == 11
clustering11 = last[oneone]

onetwo = last['cluster'] == 12
clustering12 = last[onetwo]

onethree = last['cluster'] == 13
clustering13 = last[onethree]

onefour = last['cluster'] == 14
clustering14 = last[onefour]

onefive = last['cluster'] == 15
clustering15 = last[onefive]

onesix = last['cluster'] == 16
clustering16 = last[onesix]

oneseven = last['cluster'] ==17
clustering17 = last[oneseven]

oneeight = last['cluster'] == 18
clustering18 = last[oneeight]

onenine = last['cluster'] == 19
clustering19 = last[onenine]

twozero = last['cluster'] == 20
clustering20 = last[twozero]

twoone = last['cluster'] == 21
clustering21 = last[twoone]

twotwo = last['cluster'] == 22
clustering22 = last[twotwo]

twothree = last['cluster'] == 23
clustering23 = last[twothree]

twofour = last['cluster'] == 24
clustering24 = last[twofour]

twofive = last['cluster'] == 25
clustering25 = last[twofive]

twosix = last['cluster'] == 26
clustering26 = last[twosix]

twoseven = last['cluster'] == 27
clustering27 = last[twoseven]

twoeight = last['cluster'] == 28
clustering28 = last[twoeight]

twonine = last['cluster'] == 29
clustering29 = last[twonine]

threezero = last['cluster'] == 30
clustering29 = last[threezero]

threeone = last['cluster'] == 31
clustering31 = last[threeone]

threetwo = last['cluster'] == 32
clustering32 = last[threetwo]

threethree = last['cluster'] == 33
clustering33 = last[threethree]

threefour = last['cluster'] == 34
clustering34 = last[twonine]

threefive = last['cluster'] == 35
clustering35 = last[threefive]

threesix = last['cluster'] == 36
clustering36 = last[threesix]

threeseven = last['cluster'] == 37
clustering37 = last[threeseven]

threeeight = last['cluster'] == 38
clustering38 = last[threeeight]

threenine = last['cluster'] == 39
clustering39 = last[threenine]

zero = last['cluster'] == 0
clustering0 = last[zero]

# %%
last = gpd.GeoDataFrame(
    last, geometry='geometry')

# %%
clustering1
# Out:
#          gid  cluster                                           geometry  \
# 30252  06303        1  POLYGON ((959901.214 1942520.352, 959916.600 1...
# 30253  06303        1  POLYGON ((959901.214 1942520.352, 959916.600 1...
# 30254  06303        1  POLYGON ((959901.214 1942520.352, 959916.600 1...
# 30255  06303        1  POLYGON ((959901.214 1942520.352, 959916.600 1...
# 30256  06303        1  POLYGON ((959901.214 1942520.352, 959916.600 1...
# ...      ...      ...                                                ...
# 33370  06312        1  POLYGON ((960168.256 1942027.438, 960184.258 1...
# 33371  06312        1  POLYGON ((960168.256 1942027.438, 960184.258 1...
# 33372  06312        1  POLYGON ((960168.256 1942027.438, 960184.258 1...
# 33373  06312        1  POLYGON ((960168.256 1942027.438, 960184.258 1...
# 33374  06312        1  POLYGON ((960168.256 1942027.438, 960184.258 1...
#
#        totval
# 30252    88.0
# 30253    88.0
# 30254    88.0
# 30255    88.0
# ...

# %%
clustering1 = gpd.GeoDataFrame(clustering1, geometry = clustering1.geometry)
clustering2 = gpd.GeoDataFrame(clustering2, geometry = clustering2.geometry)
clustering3 = gpd.GeoDataFrame(clustering3, geometry = clustering3.geometry)
clustering4 = gpd.GeoDataFrame(clustering4, geometry = clustering4.geometry)
clustering5 = gpd.GeoDataFrame(clustering5, geometry = clustering5.geometry)
clustering6 = gpd.GeoDataFrame(clustering6, geometry = clustering6.geometry)
clustering7 = gpd.GeoDataFrame(clustering7, geometry = clustering7.geometry)
clustering8 = gpd.GeoDataFrame(clustering8, geometry = clustering8.geometry)
clustering9 = gpd.GeoDataFrame(clustering9, geometry = clustering9.geometry)
clustering10 = gpd.GeoDataFrame(clustering10, geometry = clustering10.geometry)
clustering11 = gpd.GeoDataFrame(clustering11, geometry = clustering11.geometry)
clustering12 = gpd.GeoDataFrame(clustering12, geometry = clustering12.geometry)
clustering13 = gpd.GeoDataFrame(clustering13, geometry = clustering13.geometry)
clustering14 = gpd.GeoDataFrame(clustering14, geometry = clustering14.geometry)
clustering15 = gpd.GeoDataFrame(clustering15, geometry = clustering15.geometry)
clustering16 = gpd.GeoDataFrame(clustering16, geometry = clustering16.geometry)
clustering17 = gpd.GeoDataFrame(clustering17, geometry = clustering17.geometry)
clustering18 = gpd.GeoDataFrame(clustering18, geometry = clustering18.geometry)
clustering19 = gpd.GeoDataFrame(clustering19, geometry = clustering19.geometry)
clustering20 = gpd.GeoDataFrame(clustering20, geometry = clustering20.geometry)
clustering21 = gpd.GeoDataFrame(clustering21, geometry = clustering21.geometry)
clustering22 = gpd.GeoDataFrame(clustering22, geometry = clustering22.geometry)
clustering23 = gpd.GeoDataFrame(clustering23, geometry = clustering23.geometry)
clustering24 = gpd.GeoDataFrame(clustering24, geometry = clustering24.geometry)
clustering25 = gpd.GeoDataFrame(clustering25, geometry = clustering25.geometry)
clustering26 = gpd.GeoDataFrame(clustering26, geometry = clustering26.geometry)
clustering27 = gpd.GeoDataFrame(clustering27, geometry = clustering27.geometry)
clustering28 = gpd.GeoDataFrame(clustering28, geometry = clustering28.geometry)
clustering29 = gpd.GeoDataFrame(clustering29, geometry = clustering29.geometry)
clustering30 = gpd.GeoDataFrame(clustering30, geometry = clustering30.geometry)
clustering31 = gpd.GeoDataFrame(clustering31, geometry = clustering31.geometry)
clustering32 = gpd.GeoDataFrame(clustering32, geometry = clustering32.geometry)
clustering33 = gpd.GeoDataFrame(clustering33, geometry = clustering33.geometry)
clustering34 = gpd.GeoDataFrame(clustering34, geometry = clustering34.geometry)
clustering35 = gpd.GeoDataFrame(clustering35, geometry = clustering35.geometry)
clustering36 = gpd.GeoDataFrame(clustering36, geometry = clustering36.geometry)
clustering37 = gpd.GeoDataFrame(clustering37, geometry = clustering37.geometry)
clustering38 = gpd.GeoDataFrame(clustering38, geometry = clustering38.geometry)
clustering39 = gpd.GeoDataFrame(clustering39, geometry = clustering39.geometry)
clustering0 = gpd.GeoDataFrame(clustering0, geometry = clustering0.geometry)

# %%
clustering1.to_file("clustering1.shp")
clustering2.to_file("clustering2.shp")
clustering3.to_file("clustering3.shp")
clustering4.to_file("clustering4.shp")
clustering5.to_file("clustering5.shp")
clustering6.to_file("clustering6.shp")
clustering7.to_file("clustering7.shp")
clustering8.to_file("clustering8.shp")
clustering9.to_file("clustering9.shp")
clustering10.to_file("clustering10.shp")
clustering11.to_file("clustering11.shp")
clustering12.to_file("clustering12.shp")
clustering13.to_file("clustering13.shp")
clustering14.to_file("clustering14.shp")
clustering15.to_file("clustering15.shp")
clustering16.to_file("clustering16.shp")
clustering17.to_file("clustering17.shp")
clustering18.to_file("clustering18.shp")
clustering19.to_file("clustering19.shp")
clustering20.to_file("clustering20.shp")
clustering21.to_file("clustering21.shp")
clustering22.to_file("clustering22.shp")
clustering23.to_file("clustering23.shp")
clustering24.to_file("clustering24.shp")
clustering25.to_file("clustering25.shp")
clustering26.to_file("clustering26.shp")
clustering27.to_file("clustering27.shp")
clustering29.to_file("clustering29.shp")
clustering30.to_file("clustering30.shp")
clustering31.to_file("clustering31.shp")
clustering32.to_file("clustering32.shp")
clustering33.to_file("clustering33.shp")
clustering34.to_file("clustering34.shp")
clustering35.to_file("clustering35.shp")
clustering36.to_file("clustering36.shp")
clustering37.to_file("clustering37.shp")
clustering38.to_file("clustering38.shp")
clustering39.to_file("clustering39.shp")
clustering0.to_file("clustering0.shp")
